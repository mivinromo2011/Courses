# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\dharsan\\OneDrive\\Desktop\\codechef\\training_data_with_weather_info_week_1.csv")

# %%
df
# Out:
#           Id Province/State Country/Region      Lat     Long        Date  \
# 0          1            NaN    Afghanistan  33.0000  65.0000  2020-01-22
# 1          2            NaN    Afghanistan  33.0000  65.0000  2020-01-23
# 2          3            NaN    Afghanistan  33.0000  65.0000  2020-01-24
# 3          4            NaN    Afghanistan  33.0000  65.0000  2020-01-25
# 4          5            NaN    Afghanistan  33.0000  65.0000  2020-01-26
# ...      ...            ...            ...      ...      ...         ...
# 17887  26378            NaN         Zambia -15.4167  28.2833  2020-03-20
# 17888  26379            NaN         Zambia -15.4167  28.2833  2020-03-21
# 17889  26380            NaN         Zambia -15.4167  28.2833  2020-03-22
# 17890  26381            NaN         Zambia -15.4167  28.2833  2020-03-23
# 17891  26382            NaN         Zambia -15.4167  28.2833  2020-03-24
#
#        ConfirmedCases  Fatalities  day_from_jan_first  temp   min   max  \
# ...

# %%
df.isnull().sum()
# Out:
# Id                       0
# Province/State        9702
# Country/Region           0
# Lat                      0
# Long                     0
# Date                     0
# ConfirmedCases           0
# Fatalities               0
# day_from_jan_first       0
# temp                     0
# min                    137
# max                     16
# stp                      0
# slp                   6947
# dewp                   618
# rh                     618
# ah                     618
# wdsp                     0
# prcp                     0
# fog                      0
# dtype: int64

# %%
df.fillna(df.mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                       0
# Province/State        9702
# Country/Region           0
# Lat                      0
# Long                     0
# Date                     0
# ConfirmedCases           0
# Fatalities               0
# day_from_jan_first       0
# temp                     0
# min                      0
# max                      0
# stp                      0
# slp                      0
# dewp                     0
# rh                       0
# ah                       0
# wdsp                     0
# prcp                     0
# fog                      0
# dtype: int64

# %%
df=df[df['Country/Region']=='US']

# %%
df.corr()['ConfirmedCases']
# Out:
# Id                    0.013339
# Lat                   0.027796
# Long                 -0.000151
# ConfirmedCases        1.000000
# Fatalities            0.818311
# day_from_jan_first    0.136952
# temp                 -0.003853
# min                  -0.004908
# max                   0.003703
# stp                   0.002117
# slp                   0.058066
# dewp                  0.005410
# rh                    0.025018
# ah                    0.001565
# wdsp                 -0.010820
# prcp                 -0.014824
# fog                   0.031320
# Name: ConfirmedCases, dtype: float64

# %%
corrmat = df[['ConfirmedCases', 'Fatalities', 'temp', 'min', 'max', 'stp', 'wdsp', 'prcp', 'fog','wdsp','stp','slp']].corr()
plt.subplots(figsize=(15,15))
sns.heatmap(corrmat, vmax=0.9, square=True, annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X=df[[ 'Fatalities','temp','max', 'stp', 'slp', 'dewp', 'wdsp', 'fog']]
Y=df[['ConfirmedCases']]

# %%
X.isnull().sum()
# Out:
# Fatalities    0
# temp          0
# max           0
# stp           0
# slp           0
# dewp          0
# wdsp          0
# fog           0
# dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2,random_state=400)

# %%
regr = LinearRegression()
  
regr.fit(X_train, Y_train)
print(regr.score(X_test, Y_test))
# Out:
# 0.7654106061170302

# %%
regr.coef_
# Out:
# array([[ 7.14650220e+01, -8.91678915e-01,  1.20295930e+00,
#          2.24708571e-02,  2.61241291e+00, -6.38356455e-03,
#          1.51605420e-02,  9.70175954e+00]])
