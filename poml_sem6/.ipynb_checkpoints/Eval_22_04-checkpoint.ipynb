# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("training_data_with_weather_info_week_1.csv")

# %%
df.head()
# Out:
#    Id Country_Region Province_State        Date  ConfirmedCases  Fatalities  \
# 0   1    Afghanistan            NaN  2020-01-22             0.0         0.0
# 1   2    Afghanistan            NaN  2020-01-23             0.0         0.0
# 2   3    Afghanistan            NaN  2020-01-24             0.0         0.0
# 3   4    Afghanistan            NaN  2020-01-25             0.0         0.0
# 4   5    Afghanistan            NaN  2020-01-26             0.0         0.0
#
#   country+province   Lat  Long  day_from_jan_first  ...   min   max    stp  \
# 0     Afghanistan-  33.0  65.0                  22  ...  33.6  54.9  999.9
# 1     Afghanistan-  33.0  65.0                  23  ...  32.7  55.9  999.9
# 2     Afghanistan-  33.0  65.0                  24  ...  36.9  43.2  999.9
# 3     Afghanistan-  33.0  65.0                  25  ...  37.9  56.3  999.9
# 4     Afghanistan-  33.0  65.0                  26  ...  36.1  53.1  999.9
#
#       slp  dewp        rh        ah  wdsp   prcp  fog
# ...

# %%
df.describe()
# Out:
#                 Id  ConfirmedCases    Fatalities           Lat          Long  \
# count  24414.00000    24414.000000  24414.000000  24414.000000  24414.000000
# mean   17823.50000      835.249447     39.778201     24.359897      4.101068
# std    10300.68915     6554.109673    494.078524     23.619643     78.593946
# min        1.00000        0.000000      0.000000    -51.694444   -157.498300
# 25%     8912.25000        0.000000      0.000000     12.134722    -70.035800
# 50%    17823.50000        0.000000      0.000000     30.617100      9.550000
# 75%    26734.75000       75.000000      0.000000     41.902900     55.247100
# max    35646.00000   151061.000000  17669.000000     64.963100    178.450000
#
#        day_from_jan_first          temp           min           max  \
# count        24414.000000  24414.000000  24299.000000  24388.000000
# mean            60.500000     57.584509     48.455665     66.997486
# std             22.515271     22.115746     22.744141     21.984603
# ...

# %%
df.shape
# Out:
# (24414, 21)

# %%
df.dtypes
# Out:
# Id                      int64
# Country_Region         object
# Province_State         object
# Date                   object
# ConfirmedCases        float64
# Fatalities            float64
# country+province       object
# Lat                   float64
# Long                  float64
# day_from_jan_first      int64
# temp                  float64
# min                   float64
# max                   float64
# stp                   float64
# slp                   float64
# dewp                  float64
# rh                    float64
# ah                    float64
# wdsp                  float64
# prcp                  float64
# fog                     int64
# dtype: object

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Id                        0
# Country_Region            0
# Province_State        14040
# Date                      0
# ConfirmedCases            0
# Fatalities                0
# country+province          0
# Lat                       0
# Long                      0
# day_from_jan_first        0
# temp                      0
# min                     115
# max                      26
# stp                       0
# slp                   10105
# dewp                    628
# rh                      628
# ah                      628
# wdsp                      0
# prcp                      0
# fog                       0
# dtype: int64

# %%
df.nunique()
# Out:
# Id                    24414
# Country_Region          184
# Province_State          133
# Date                     78
# ConfirmedCases         2218
# Fatalities              531
# country+province        313
# Lat                     307
# Long                    311
# day_from_jan_first       78
# temp                   1089
# min                     626
# max                     617
# stp                    2385
# slp                     562
# dewp                   1040
# rh                    19694
# ah                    19751
# wdsp                    304
# prcp                    243
# fog                       2
# dtype: int64

# %%
df=df[df['Country_Region']

# %%
country_grouped_covid = df[0:1]

# %%
for country in country_list:
    test_data = df['Country_Region'] == country   
    test_data = df[test_data]
    country_grouped_covid = pd.concat([country_grouped_covid, test_data], axis=0)

# %%
country_grouped_covid.head()
# Out:
#    Id Country_Region Province_State        Date  ConfirmedCases  Fatalities  \
# 0   1    Afghanistan            NaN  2020-01-22             0.0         0.0
# 0   1    Afghanistan            NaN  2020-01-22             0.0         0.0
# 1   2    Afghanistan            NaN  2020-01-23             0.0         0.0
# 2   3    Afghanistan            NaN  2020-01-24             0.0         0.0
# 3   4    Afghanistan            NaN  2020-01-25             0.0         0.0
#
#   country+province   Lat  Long  day_from_jan_first  ...   min   max    stp  \
# 0     Afghanistan-  33.0  65.0                  22  ...  33.6  54.9  999.9
# 0     Afghanistan-  33.0  65.0                  22  ...  33.6  54.9  999.9
# 1     Afghanistan-  33.0  65.0                  23  ...  32.7  55.9  999.9
# 2     Afghanistan-  33.0  65.0                  24  ...  36.9  43.2  999.9
# 3     Afghanistan-  33.0  65.0                  25  ...  37.9  56.3  999.9
#
#       slp  dewp        rh        ah  wdsp   prcp  fog
# ...

# %%
country_grouped_covid['Province_State'].replace(np.nan, "Not Reported", inplace=True)

# %%
country_grouped_covid.head()
# Out:
#    Id Country_Region Province_State        Date  ConfirmedCases  Fatalities  \
# 0   1    Afghanistan   Not Reported  2020-01-22             0.0         0.0
# 0   1    Afghanistan   Not Reported  2020-01-22             0.0         0.0
# 1   2    Afghanistan   Not Reported  2020-01-23             0.0         0.0
# 2   3    Afghanistan   Not Reported  2020-01-24             0.0         0.0
# 3   4    Afghanistan   Not Reported  2020-01-25             0.0         0.0
#
#   country+province   Lat  Long  day_from_jan_first  ...   min   max    stp  \
# 0     Afghanistan-  33.0  65.0                  22  ...  33.6  54.9  999.9
# 0     Afghanistan-  33.0  65.0                  22  ...  33.6  54.9  999.9
# 1     Afghanistan-  33.0  65.0                  23  ...  32.7  55.9  999.9
# 2     Afghanistan-  33.0  65.0                  24  ...  36.9  43.2  999.9
# 3     Afghanistan-  33.0  65.0                  25  ...  37.9  56.3  999.9
#
#       slp  dewp        rh        ah  wdsp   prcp  fog
# ...

# %%
country_grouped_covid.corr()['ConfirmedCases']
# Out:
# Id                    0.000318
# ConfirmedCases        1.000000
# Fatalities            0.869959
# Lat                   0.075184
# Long                  0.027472
# day_from_jan_first    0.144556
# temp                 -0.038616
# min                  -0.042105
# max                  -0.039770
# stp                  -0.036901
# slp                   0.018708
# dewp                 -0.032645
# rh                    0.002865
# ah                    0.005513
# wdsp                 -0.012334
# prcp                 -0.028524
# fog                  -0.005253
# Name: ConfirmedCases, dtype: float64

# %%
c_mat_weat = country_grouped_covid[['ConfirmedCases', 'Fatalities', 'temp','min','max','prcp','fog', 'prcp','wdsp','stp','slp','dewp','rh','ah']].corr()

# %%
df['Date']
# Out:
# 0        2020-01-22
# 1        2020-01-23
# 2        2020-01-24
# 3        2020-01-25
# 4        2020-01-26
#             ...
# 24409    2020-04-04
# 24410    2020-04-05
# 24411    2020-04-06
# 24412    2020-04-07
# 24413    2020-04-08
# Name: Date, Length: 24414, dtype: object

# %%
plt.subplots(figsize=(12,12))
sns.heatmap(c_mat_weat,vmin=-0.18,annot=True, vmax=1, center= 0.5,linewidths=3, linecolor='black')
# Out:
# <AxesSubplot:>

# %%
## Inferences from correlation analysis:
# All the factors related to weather have similar affect on confirmed cases and Fatalities
# But it is not clear whether on whether these parameters affect the value of confirmed cases and fatalities

# %%
## LEARNING
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
country_grouped_covid = country_grouped_covid[country_grouped_covid['slp'].notnull()]
country_grouped_covid = country_grouped_covid[country_grouped_covid['rh'].notnull()]
country_grouped_covid = country_grouped_covid[country_grouped_covid['ah'].notnull()]

# %%
Y=country_grouped_covid[['ConfirmedCases']]
X=country_grouped_covid[[ 'Fatalities','temp','prcp','fog','wdsp','slp','rh']]
X.isnull().sum()
# Out:
# Fatalities    0
# temp          0
# prcp          0
# fog           0
# wdsp          0
# slp           0
# rh            0
# dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2,random_state=400)
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
print(model.score(X_test, Y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-4f86fe677c5b> in <module>
# ----> 1 model.fit(X_train, Y_train)
#       2 print(model.score(X_test, Y_test))
#
# ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~/.local/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...
